# %% [markdown]
# # Exam
#
# In this exam, we will work with the "frequently requested health data” from the OECD.
# Your task is to compute a simple “efficiency score” and make three plots.
#
#
# You will earn a higher grade if you provide nicer graphs.

# %% [markdown]
# Now you need to call the libaries
#
# * ggplot2
# * dplyr

# %%
library(ggplot2)

# %%
library(dplyr)

# %% [markdown]
# Now you have to read the de data that we have cleaned during tutorial 3. The csv file is called oecddata.csv

# %%
oecd <- read.csv2("oecddata.csv")

# %% [markdown]
# To see how the data look like, use the command:
#
# head(oecd)
#
# With the command
#
# oecd
#
#
# You can see the dataset in total.

# %%
head(oecd)
# Out:
#   X Country   Year Cost     LE
# 1 1 Australia 2005 2842.132 80.9
# 2 2 Australia 2006 3023.098 81.1
# 3 3 Australia 2007 3196.226 81.4
# 4 4 Australia 2008 3310.171 81.5
# 5 5 Australia 2009 3564.405 81.6
# 6 6 Australia 2010 3607.341 81.8

# %% [markdown]
# ## Graphs

# %% [markdown]
# To make the graphs we need to make selections of the data. Please use "dplyr" (commands "select" and "filter") and the "pipe". The first assignment is to make a scatterplot using "ggplot". The graph contains data for all countries for the year 2014. Therefore make a dataframe with dplyr first, called "graph1" with the required data.
# Then, make a scatterplot with "Cost" on the x-axis and "LE" on the y-axis. You have to add a regression line with a shaded area for the confidence interval.

# %%
graph1 <- subset(oecd, Year==2014)
graph1
# Out:
#     X   Country         Year Cost      LE
# 10   10 Australia       2014 4206.8516 82.4
# 21   21 Austria         2014 4895.9992 81.6
# 32   32 Belgium         2014 4522.0450 81.4
# 43   43 Canada          2014 4491.7648   NA
# 54   54 Chile           2014 1688.5233 79.0
# 65   65 Czech Republic  2014 2386.3385 78.9
# 76   76 Denmark         2014 4857.0285 80.8
# 87   87 Estonia         2014 1724.5100 77.2
# 98   98 Finland         2014 3870.4000 81.3
# 109 109 France          2014 4366.9864 82.8
# 120 120 Germany         2014 5119.2146 81.2
# 131 131 Greece          2014 2220.1065 81.5
# 142 142 Hungary         2014 1796.6034 75.9
# 153 153 Iceland         2014 3896.9251 82.9
# 164 164 Ireland         2014 5001.3220 81.4
# 175 175 Israel          2014 2547.4010 82.2
# 186 186 Italy           2014 3206.8286 83.2
# 197 197 Japan           2014 4152.3727 83.7
# 208 208 Korea           2014 2361.4400 82.2
# 219 219 Latvia          2014 1295.0128 74.3
# ...

# %%
ggplot(graph1, aes(x = Cost, y = LE)) +geom_point() +geom_smooth(method=lm)
# Out:
# Warning message:
# "Removed 1 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 1 rows containing missing values (geom_point)."
# plot without title

# %% [markdown]
# The second assignment is to make a line graph. You will use the years 2005-2015 for 5 countries (you can choose your own countries). Make a new dataframe called graph2 with the required data. Then, make a line graph with "Year"  and "Cost" on the y-axis. There should be coloured lines per country and a legend attached.

# %%
graph2 <- subset(oecd, Country=="Australia" | Country=="Austria" | Country=="Belgium" | Country=="Chile" | Country=="Denmark")
graph2
# Out:
#    X  Country   Year Cost      LE
# 1   1 Australia 2005 2842.1321 80.9
# 2   2 Australia 2006 3023.0978 81.1
# 3   3 Australia 2007 3196.2260 81.4
# 4   4 Australia 2008 3310.1708 81.5
# 5   5 Australia 2009 3564.4049 81.6
# 6   6 Australia 2010 3607.3407 81.8
# 7   7 Australia 2011 3794.0874 82.0
# 8   8 Australia 2012 3807.6819 82.1
# 9   9 Australia 2013 4176.8530 82.2
# 10 10 Australia 2014 4206.8516 82.4
# 11 11 Australia 2015 4420.4364   NA
# 12 12 Austria   2005 3324.0795 79.4
# 13 13 Austria   2006 3567.6495 80.0
# 14 14 Austria   2007 3718.7390 80.3
# 15 15 Austria   2008 3964.8495 80.5
# 16 16 Austria   2009 4119.7452 80.4
# 17 17 Austria   2010 4236.3164 80.7
# 18 18 Austria   2011 4362.3426 81.1
# 19 19 Austria   2012 4646.4365 81.0
# 20 20 Austria   2013 4806.3934 81.2
# 21 21 Austria   2014 4895.9992 81.6
# 22 22 Austria   2015 5015.6372   NA
# 23 23 Belgium   2005 2985.8089 79.1
# 24 24 Belgium   2006 3136.9155 79.5
# 25 25 Belgium   2007 3286.2254 79.9
# ...

# %%
ggplot(graph2, aes(x = Year, y = Cost, col = Country)) + geom_line() + scale_x_continuous(breaks=c(2005:2016))
# Out:
# plot without title

# %% [markdown]
# ## Efficiency scores
#
# The last assignment is to compute simple effiency scores. We will use the year 2014 for all countries (i.e. the dataframe "graph1").
# Make a new dateframe called "eff" (using graph1). Please use the "pipe" to execute to following steps:
# Select all the variables except the NA's (hint: use na.omit) and create a new column called "Ratio" with mutate. Ratio is defined as "Cost/LE" (cost per output).
# Create a new column called "Score" with mutate. Score is the ratio per country divided by the lowest ratio in the dataframe.
# To complete this dataframe order the dataset using "arrange" based on score (i.e. lowest Score first).
#
#
# Finally make a bar chart using ggplot. Countries should be on the x-axis and "Score" on the y-axis.
#
#
#
# You can earn extra points if you are able to order the graph based on scores (lowest first, highest last), if you are able to make the x-axis readable, make the bar of the Netherlands red and the other bars blue and/or change the name of the y-axis to "Efficiency scores according to [your name]"
#
#
# The figure should like this:
#
# ![My Figure](eff.png)

# %%
eff <- na.omit(graph1)
eff$Ratio=with(eff, Cost/LE)
eff$Score=with(eff, Ratio/min(Ratio))
eff
# Out:
#     X   Country         Year Cost      LE   Ratio     Score
# 10   10 Australia       2014 4206.8516 82.4  51.05402 4.021663
# 21   21 Austria         2014 4895.9992 81.6  59.99999 4.726361
# 32   32 Belgium         2014 4522.0450 81.4  55.55338 4.376089
# 54   54 Chile           2014 1688.5233 79.0  21.37371 1.683665
# 65   65 Czech Republic  2014 2386.3385 78.9  30.24510 2.382488
# 76   76 Denmark         2014 4857.0285 80.8  60.11174 4.735164
# 87   87 Estonia         2014 1724.5100 77.2  22.33821 1.759641
# 98   98 Finland         2014 3870.4000 81.3  47.60640 3.750084
# 109 109 France          2014 4366.9864 82.8  52.74138 4.154581
# 120 120 Germany         2014 5119.2146 81.2  63.04451 4.966186
# 131 131 Greece          2014 2220.1065 81.5  27.24057 2.145813
# 142 142 Hungary         2014 1796.6034 75.9  23.67066 1.864602
# 153 153 Iceland         2014 3896.9251 82.9  47.00754 3.702911
# 164 164 Ireland         2014 5001.3220 81.4  61.44130 4.839897
# ...

# %%
eff <-arrange(eff, Score)
eff
# Out:
#    X   Country         Year Cost      LE   Ratio     Score
# 1  362 Turkey          2014  990.1908 78.0  12.69475 1.000000
# 2  241 Mexico          2014 1035.3389 74.8  13.84143 1.090327
# 3  219 Latvia          2014 1295.0128 74.3  17.42951 1.372970
# 4  285 Poland          2014 1624.8655 77.7  20.91204 1.647298
# 5   54 Chile           2014 1688.5233 79.0  21.37371 1.683665
# 6   87 Estonia         2014 1724.5100 77.2  22.33821 1.759641
# 7  142 Hungary         2014 1796.6034 75.9  23.67066 1.864602
# 8  307 Slovak Republic 2014 1970.5230 76.9  25.62449 2.018510
# 9  131 Greece          2014 2220.1065 81.5  27.24057 2.145813
# 10 208 Korea           2014 2361.4400 82.2  28.72798 2.262981
# 11  65 Czech Republic  2014 2386.3385 78.9  30.24510 2.382488
# 12 175 Israel          2014 2547.4010 82.2  30.99028 2.441188
# 13 296 Portugal        2014 2583.8438 81.2  31.82074 2.506605
# 14 318 Slovenia        2014 2598.9066 81.2  32.00624 2.521218
# ...

# %%
eff$Color = ifelse(eff$Country=="Netherlands", "red", "blue")
kleurtjes <- eff[['Color']]
ggplot(eff, aes(x = reorder (Country, Score), y = Score, fill = Color)) + theme(axis.text.x=element_text(angle = 45, hjust = 1))+ geom_bar(stat="identity", fill = kleurtjes)+ scale_x_discrete("Country") + scale_y_continuous("Efficiency score acoording to Stefan Martens")
# Out:
# plot without title
